# %%
100 / 12
# Out:
# 8.333333333333334

# %%
round(100 /12)
# Out:
# 8

# %%
t = 'hello world'
print(t)
# Out:
# hello world

# %%
# импорт функции из стандартной библиотеки
from math import factorial

# %%
factorial(10)*0.5
# Out:
# 1814400.0

# %% [markdown]
# # Header
# Сколько решеток, такой уровень у заголовка (одна решетка - заголовок первого уровня).
#
# # Ввод формул Latex
# Далее ввод формулы Latex (два символа доллара $$)

# %% [markdown]
# $$ c = \sqrt{a^2 + b^2} $$

# %% [markdown]
# Есть возможность вызывать bash или консоль прямо из ноутбука, а также передавать туда переменные (знак доллара $ и имя переменной):

# %%
! echo "Hello, world!"
# Out:
# "Hello, world!"

# %%
t = 'Hello, world!'
! echo $t
# Out:
# Hello, world!

# %% [markdown]
# ## Cell magic
#
# Вызов терминала с набором нескольких команд (не забываем сменить кодировку):

# %%
# %%cmd
# chcp 65001
# cd ..
# dir
# Out:
# Microsoft Windows [Version 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation.  All rights reserved.
#
# (base) C:\Users\GLFS\mathandpython\week1>chcp 65001
# Active code page: 65001
#
# (base) C:\Users\GLFS\mathandpython\week1>cd ..
#
# (base) C:\Users\GLFS\mathandpython>dir
#  Volume in drive C has no label.
#  Volume Serial Number is B009-5793
#
#  Directory of C:\Users\GLFS\mathandpython
#
# 10.08.2019  00:34    <DIR>          .
# 10.08.2019  00:34    <DIR>          ..
# 10.08.2019  00:54    <DIR>          week1
#                0 File(s)              0 bytes
#                3 Dir(s)  447В 751В 618В 560 bytes free
#
# (base) C:\Users\GLFS\mathandpython>

# %% [markdown]
# ## Список команд cell magic

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# ## Работа с графикой pylab

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
y = range(11)
print(y)
plot(y)
# Out:
# range(0, 11)

# %%
import numpy
numpy.__version__
# Out:
# '1.16.4'

# %%
import scipy
scipy.__version__
# Out:
# '1.2.1'

# %%
import pandas
pandas.__version__
# Out:
# '0.24.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.0'
